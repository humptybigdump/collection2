# %% [markdown]
# # Markovitz Portfolio Selection

# %%
using DataFrames
using CSV
using Plots
using Statistics
using Dates
using SymPy
using JuMP
using COSMO
# Out:
# (process:36216): GLib-GIO-WARNING **: 18:56:27.737: Failed to open application manifest `C:\Windows\SystemApps\Microsoft.MicrosoftEdge_8wekyb3d8bbwe\AppxManifest.xml' for package #42 (`Microsoft.MicrosoftEdge_44.22621.2134.0_neutral__8wekyb3d8bbwe'): error code 0x2

# %%
# Load the data and visualize first rows
data = DataFrames.DataFrame(CSV.File("data/all_stocks_5yr.csv"));
print(first(data, 5))
stocks = Dict()
for (key, subdf) in pairs(groupby(data, :Name))
    stocks[key.Name] = copy(subdf)
end
# Out:
# 5×7 DataFrame
#  Row │ Date        Open      High      Low       Close    Volume     Name
#      │ Date        Float64?  Float64?  Float64?  Float64  Float64?   String15
# ─────┼────────────────────────────────────────────────────────────────────────
#    1 │ 2012-08-13     92.29     92.59     91.74    92.4   2.07539e6  MMM
#    2 │ 2012-08-14     92.36     92.5      92.01    92.3   1.84348e6  MMM
#    3 │ 2012-08-15     92.0      92.74     91.94    92.54  1.9834e6   MMM
#    4 │ 2012-08-16     92.75     93.87     92.21    93.74  3.39514e6  MMM
#    5 │ 2012-08-17     93.93     94.3      93.59    94.24  3.06951e6  MMM

# %%
# Get a fixed order of the stocks
#stock_names = collect(keys(stocks));
stock_names = unique(keys(stocks));

# randomly select some stocks to reduce the amount of data
N_stocks = 110
stocks_selected = rand(stock_names, N_stocks);

# delete some stocks
for name in stock_names
    if name in stocks_selected
        continue
    end
    delete!(stocks, name)
end;

# adapt stock_names array after stock deletion
stock_names = collect(keys(stocks));
N_stocks = length(stock_names);

# %%
# Visualize evolution of stock changes for some examples
plot(stocks[stock_names[1]].Date, stocks[stock_names[1]].Close / first(stocks[stock_names[1]].Close); label=stock_names[1], legend=:topleft)
plot!(stocks[stock_names[2]].Date, stocks[stock_names[2]].Close / first(stocks[stock_names[2]].Close); label=stock_names[2])
plot!(stocks[stock_names[3]].Date, stocks[stock_names[3]].Close / first(stocks[stock_names[3]].Close); label=stock_names[3])

# %% [markdown]
# ## Calculate Statistical Quantities

# %%
# Calculate the daily change
for k in keys(stocks)
   select!(stocks[k], :Name, :Date, :Open, :Close, [:Open,:Close] => ByRow((o,c) -> c/o) => :Change)
end

# %%
# plot the daily changes for an example in a histogram
stock_number = 4
histogram(filter(x -> x !== missing, stocks[stock_names[stock_number]].Change), label=stock_names[stock_number])
xlabel!("relative daily change")
ylabel!("counts")

# %%
# ===============================================================================
# Compute the average of the daily changes for each stock
# Hint: As done for plotting the histogram above you should filter out missing values
avg = zeros(N_stocks)

for (k,name) in enumerate(stock_names)
   avg[k] = mean(filter(x -> x !== missing, stocks[name].Change))
end

# ===============================================================================

# %%
# define a function to compute the covariance of two distributions s1 and s2
# s1, s2: input arrays containing stock changes
function covariance(s1, s2)

    l = min(length(s1), length(s2))
    # make sure that both stocks have data at the same day!
    gi = filter(i -> s1[i] !== missing && s2[i] !== missing, 1:l) # good indices
    l = length(gi)
    
    # ===============================================================================
    # Compute the covariance
    m1 = sum(s1[gi]) / l
    m2 = sum(s2[gi]) / l
    covariance = sum((s1[gi] .- m1) .* (s2[gi] .- m2)) / (l-1)
    # ===============================================================================
    return covariance
end
# Out:
# covariance (generic function with 1 method)

# %%
# =============================================================================================
# Compute the covariance matrix

covar = zeros(N_stocks ,N_stocks)
for i=1:N_stocks , j=1:N_stocks 
    covar[i,j] = covariance(stocks[stock_names[i]].Change, stocks[stock_names[j]].Change)
end
# =============================================================================================

# %%
# =============================================================================================
# Compute the Variance for each stock
# Hint: As done for plotting the histogram above you should filter out missing values
variance = zeros(N_stocks)

for (k,name) in enumerate(stock_names)
    changes = filter(x -> x !== missing, stocks[name].Change)
    variance[k] = covariance(changes, changes)
end
# =============================================================================================

# %%
# Show annualized standard deviation and average
fig = scatter([], [], xlabel="Annualized Standard Deviation", ylim=(0.75,1.7), xlim=(-0.01,.4), ylabel="Annualized Expected Value", labels=:none, legend=:topleft)
for k=1:N_stocks 
    scatter!([sqrt(variance[k]) * sqrt(252)], [avg[k]^252], labels=:none, markercolor=:blue)
end
scatter!([0.0], [1.02], label="Government Bonds", markercolor=:red)

# %%
# Compute correlation between stocks and visualize in a heatmap

corre = zeros(N_stocks,N_stocks)
for i=1:N_stocks , j=1:N_stocks
    corre[i,j] = covar[i,j] / (sqrt(variance[i])*sqrt(variance[j]))
end

heatmap(corre, yflip=true, aspect_ratio=:equal, size=(300,300))

# %% [markdown]
# ## Optimize Portfolio

# %%
# =============================================================================================
# Optimize your portfolio by using the COSMO Optimizer (Quadratic solver).
# Choose your favourite form of the optimization problem (lecture 5, slide 21).
# Depending on your choice, try different values for the minimum expected change, the maximum variance 
# or the risk aversion parameter

q = 100

model = Model(COSMO.Optimizer)
@variable(model, w[1:N_stocks])
@constraint(model, ones(N_stocks)'*w == 1)
@constraint(model, w .>= 0)
@objective(model, Max, avg'*w - q * w'*covar*w)

#@constraint(model, ones(N_stocks)'*w == 1)
#@constraint(model, w'*covar*w .<= 10)
#@constraint(model, w .>= 0)
#@objective(model, Max, avg'*w)

optimize!(model)
w_best = value.(w[1:N_stocks]);

# =============================================================================================
# Out:
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{99},
#           constraints: A ∈ R^{100x99} (198 nnz),
#           matrix size to factor: 199x199,
#           Floating-point precision: Float64
# Sets:     Nonnegatives of dim: 99
#           ZeroSet of dim: 1
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 2021.73ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	-1.6126e+00	6.1589e-01	6.0048e-01	1.0000e-01
# 25	-9.9924e-01	1.9294e-05	1.8824e-05	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: -0.9992
# Runtime: 5.843s (5843.0ms)

# %%
indices = sortperm(w_best, rev=true);
println(w_best[indices[1:5]],"\n",stock_names[indices[1:5]])
# Out:
# [0.11728867234313321, 0.08080355104400251, 0.06762510923478446, 0.06260185709553807, 0.062321254782525454]
# Any[String15("FTV"), String15("ALLE"), String15("EIX"), String15("WLTW"), String15("ZTS")]

# %%
#plot your optimized portfolio and see how your portfolio performs in comparison to single stock investments

fig = scatter([], [], xlabel="Annualized Standard Deviation", ylim=(0.75,1.7), xlim=(-0.01,.4), ylabel="Annualized Expected Value", labels=:none, legend=:topleft)
for k=1:N_stocks
    scatter!([sqrt(variance[k]) * sqrt(252)], [avg[k]^252], labels=:none, markercolor=:blue)
end
scatter!([0.0], [1.02], label="Government Bonds", markercolor=:red)

risk = w_best'*covar*w_best
ret = avg'*w_best
scatter!([sqrt(risk) * sqrt(252)], [ret^252], labels="Selected Portfolio", markercolor=:green, marker=:+, markersize=5,linewidth=20)

# %% [markdown]
# # Exercise 12.2: The inverted pendulum
#
# **Remark to generate the animations**
# * Install the ffmpeg package, e.g. by conda install ffmpeg!!
# * Beware that existing gifs might not be overwritten automatically. Make sure to always give a new name to the `animate_pendulum` function or delete the existing file.

# %%
using Luxor

import LinearAlgebra
LA = LinearAlgebra;

# %%
# define some global variables

# pendulum mass in kg
const m = 2
# cart mass in kg
const c = 8
# pole length in m
const l = 0.5
# earth acceleration in m/s²
const g = 9.81

# number of time steps for prediction horizion in MPC
T = 50
# length of time steps in s
Δt = 0.03
# time discount to weight objective function different depending on the amount of time passed
time_discount = 0.1

# number of variables of interest in optimization problem: 4 state space variables + 1 control
n = 5
# number of constraints in optimization problem
k = 4;

# %%
# Function for plotting pendulum animation
# Needs the ffmpeg package!! and a folder tmp
# Beware that existing gifs might not be overwritten automatically.
# Make sure to always give a new name or delete the existing
# p: array of cart positions for all times
# θ: array of pendulum positions for all times
# name: name of gif-file containing the animation
function animate_pendulum(p, θ, name)
    nt = length(p)

    # Create the "tmp" directory if it doesn't exist
    if !isdir("tmp")
        mkdir("tmp")
    end

    # iterate over all times and generate a png per time step
    for i = 1:nt
        @png begin
            background("white")
            factor = 350
            p1 = Point(p[i] * factor, 0)
            p2 = Point(sin(θ[i]) * factor * l, -cos(θ[i]) * factor * l) + p1
            origin()
            setline(10)
            sethue("red")
            line(p1, p2, :stroke)
            sethue("gold")
            line(Point(-1500, 0), Point(1500, 0), :stroke)
            sethue("black")
            Luxor.box(p1, 80, 40, :fill)
            circle(p2, 20, :fill)
            preview()
        end 2000 600 "tmp/" * name * "_" * lpad(i, 2, "0") * ".png"
    end

    # combine png images to gif
    loadpath = "tmp/" * name * "_"
    run(`ffmpeg -y -framerate 15.1515 -i $loadpath"%02d.png" "$name.mp4"`)

    # # Provide the full path to ffmpeg executable
    # ffmpeg_path = "C:\ffmpeg\bin\ffmpeg.exe"  # Change this to the actual path

end
# Out:
# animate_pendulum (generic function with 1 method)

# %% [markdown]
# ## Exercise 12.2b: Pendulum simulation

# %% [markdown]
# \begin{align*}
# \vec x_{t+1} = A_t \vec x_t + \vec b_t  u_t + \vec c_t\\
# A_t = \begin{pmatrix}
# 1 & 0 & \Delta t & 0\\
# 0 & 1 & 0  & \Delta t\\
# 0 & 0 & 1  & 0\\
# 0 & 0 & 0  & 1
# \end{pmatrix}\\
# \vec b_t = \begin{pmatrix}
# \Delta t \frac{-\cos(\theta_t)}{l(c+m \sin^2(\theta_t))} \frac{\Delta t}{2}\\
# \frac{\Delta t} {(c+m \sin^2(\theta_t))} \frac{\Delta t}{2}\\
# \Delta t \frac{-\cos(\theta_t)}{l(c+m \sin^2(\theta_t))}\\
# \frac{\Delta t} {(c+m \sin^2(\theta_t))}
# \end{pmatrix}\\
# \vec{c}_t =
# \begin{pmatrix}
# \Delta t \frac{(c+m) g \sin(\theta_t)-m l \sin(\theta_t) \cos(\theta_t) \dot{\theta}_t^2}{l (c+m*sin^2(\theta))} \frac{\Delta t}{2}\\
# \Delta t \frac{-m g \sin(\theta_t) \cos(\theta_t)+m l \sin(\theta_t) \dot{\theta}_t^2}{c+m \sin^2(\theta_t)} \frac{\Delta t}{2}\\
# \Delta t \frac{(c+m) g \sin(\theta_t)-m l \sin(\theta_t) \cos(\theta_t) \dot{\theta}_t^2}{l (c+m*sin^2(\theta))}\\
# \Delta t \frac{-m g \sin(\theta_t) \cos(\theta_t)+m l \sin(\theta_t) \dot{\theta}_t^2}{c+m \sin^2(\theta_t)}
# \end{pmatrix}
# \end{align*}

# %%
# returns the quantities needed to calculate x_t+1 from time x_t and u_t
function At_bt_ct(θ,dθ)
    # acceleration linear in xt
    ddθ_fixed = Δt * ((c+m)*g*sin(θ)-m*l*sin(θ)*cos(θ)*(dθ^2)) / (l*(c+m*sin(θ)^2))
    ddp_fixed = Δt * (-m*g*sin(θ)*cos(θ)+m*l*sin(θ)*dθ^2) / (c+m*sin(θ)^2)
    
    # acceleration linear in u
    ddθ_u = Δt * (-cos(θ)) / (l*(c+m*sin(θ)^2))
    ddp_u = Δt / (c+m*sin(θ)^2)
    
    At = zeros(4,4)
    bt = zeros(4)
    ct = zeros(4)
    
    # ====================================================================================================
    # Construct the matrix A and the vectors bt and ct 
    
    At = [1 0 Δt 0;
         0 1 0  Δt;
         0 0 1  0;
         0 0 0  1];
    ct = [ddθ_fixed * Δt * 0.5; ddp_fixed * Δt * 0.5; ddθ_fixed; ddp_fixed]
    bt = [ddθ_u * Δt * 0.5; ddp_u * Δt * 0.5; ddθ_u; ddp_u]
    
    # ====================================================================================================
    
    return At, bt, ct
end
# Out:
# At_bt_ct (generic function with 1 method)

# %%
# simulate the pendulum movement
# x0: initial state vector
# u: array of control for each time step
# xt: array with state vector for each time step
function simulate_pendulum(x0,u)
    x_new = copy(x0)
    
    # number of time steps extracted from the length of control vector
    nt = length(u)
    xt = Vector(undef, nt)
    
    # iterate over time steps
    for t in 1:nt
        x = x_new
        At, bt, ct = At_bt_ct(x[1],x[3])
        x_new = At*x + bt*u[t] + ct
        xt[t] = x_new
    end
    return xt
end
# Out:
# simulate_pendulum (generic function with 1 method)

# %%
# set number of time steps of size Δt for which to simulate pendulum movement
time_sim = 200
x_arr = simulate_pendulum([0.75*pi,0,0,0],zeros(time_sim));

# %%
p_initial = map(x->x[2],x_arr)
θ_initial = map(x->x[1],x_arr)

animate_pendulum(p_initial,θ_initial,"pendulum")
# Out:
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.1 (GCC) 20200523
#   configuration: --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libmfx --enable-amf --enable-ffnvcodec --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'tmp/pendulum_%02d.png':
#   Duration: 00:00:13.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 2000x600, 15.17 fps, 15.15 tbr, 15.15 tbn, 15.15 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0000019286a72000] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0000019286a72000] profile High 4:4:4 Predictive, level 3.2, 4:4:4, 8-bit
# [libx264 @ 0000019286a72000] 264 - core 160 - H.264/MPEG-4 AVC codec - Copyleft 2003-2020 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=19 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'pendulum.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 2000x600, q=-1--1, 15.15 fps, 30303 tbn, 15.15 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  200 fps=153 q=-1.0 Lsize=      99kB time=00:00:13.00 bitrate=  62.5kbits/s speed=9.96x
# video:96kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.019277%
# [libx264 @ 0000019286a72000] frame I:1     Avg QP:12.13  size:  1270
# [libx264 @ 0000019286a72000] frame P:93    Avg QP:14.02  size:   684
# [libx264 @ 0000019286a72000] frame B:106   Avg QP:20.52  size:   312
# [libx264 @ 0000019286a72000] consecutive B-frames: 17.5% 27.0% 25.5% 30.0%
# [libx264 @ 0000019286a72000] mb I  I16..4:  5.2% 94.0%  0.7%
# [libx264 @ 0000019286a72000] mb P  I16..4:  0.2%  0.3%  0.2%  P16..4:  0.3%  0.2%  0.1%  0.0%  0.0%    skip:98.9%
# [libx264 @ 0000019286a72000] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.7%  0.2%  0.1%  direct: 0.0%  skip:98.9%  L0:45.3% L1:36.8% BI:17.9%
# [libx264 @ 0000019286a72000] 8x8 transform intra:76.9% inter:21.6%
# [libx264 @ 0000019286a72000] coded y,u,v intra: 5.6% 2.4% 3.7% inter: 0.1% 0.0% 0.1%
# [libx264 @ 0000019286a72000] i16 v,h,dc,p: 48% 49%  3%  0%
# [libx264 @ 0000019286a72000] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20%  5% 75%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0000019286a72000] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 24% 31%  4%  4%  3%  3%  3%  2%
# [libx264 @ 0000019286a72000] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0000019286a72000] ref P L0: 67.4%  7.4% 13.7% 11.5%
# [libx264 @ 0000019286a72000] ref B L0: 84.1% 13.7%  2.2%
# [libx264 @ 0000019286a72000] ref B L1: 97.6%  2.4%
# [libx264 @ 0000019286a72000] kb/s:59.39
# Process(`ffmpeg -y -framerate 15.1515 -i tmp/pendulum_%02d.png pendulum.mp4`, ProcessExited(0))

# %% [markdown]
# ## Exercise 12.2d: Model predictive control

# %% [markdown]
# From the lecture we know the problem definition where we want to minimize the kinetic energy of the system (carriage + pendulum) and maximize the potential energy of the pendulum:
#
# \begin{align*}
#       \text{Kinetic Energy:} & \quad \begin{aligned}[t]
#           e_{kin,kart}(\vec x) &= \frac{1}{2} c \dot p^2\\
#           e_{kin,pend}(\vec x) &= \frac{1}{2} m \Big[(\dot p + l \color{red}{\sin(\theta)} \dot\theta)^2 + ( l \color{red}{\cos(\theta)} \dot\theta)^2 \Big]
#         \end{aligned}\\
#     \text{Potential Energy:} & \quad e_{\mathrm{pot}}(\vec x) = m\, l\, \color{red}{\cos(\theta)}\\
#     &f_{\mathrm{state}}(\vec x_t) = \tilde e_{\mathrm{kin,cart}}(\vec x_t) + \tilde e_{\mathrm{kin,pend}}(\vec x_t) - \tilde e_{\mathrm{pot}}(\vec x_t)
#   \end{align*}
#
#  To ensure that the objective $f_{\mathrm{state}}(\vec x_t)$ is a convex function we have to replace the trigonometric functions $\cos$ and $\sin$ (red terms). We use a simulation run of the current control flow and the pendulum dynamics to generate a series of $\theta$ and $p$. We use those values in order to fix and approximate the $\cos$ and $\sin$ terms before optimizing $x_t$ and $u_t$. We recompute the control flow after each time step to keep the deviations between this approximation and reality as small as possible.
#
# As you might have noticed the potential energy that would lead to an upright pendulum is no longer dependent on $\theta$ or $p$, at least not the $\theta$ and $p$ that we optimize over.
# To make the approximation work we have to introduce additional incentives. The original $e_{\mathrm{pot}}(\vec x) = m\, l\, \cos(\theta)$ would be maximized for $\theta = 0$. We therefore introduce $\theta^2$ as part of our objective:
#
# \begin{align*}
#     \min_{\substack{\vec u_0,\dots \vec u_{T-1},\\\vec x_1,\dots, \vec x_T}} \quad & \sum_{t=1}^{T} \left[ f_{\mathrm{state}}(\vec x_t) + \vec u_t^\top R \vec u_t + \theta_t^2\right]\\
#   \end{align*}
#
#  Additionally we would like to keep the pendulum centered to the screen. We therefore also require $p$ to be close to 0. Hence, we add the term $p^2$:
#
#  \begin{align*}
#     \min_{\substack{\vec u_0,\dots \vec u_{T-1},\\\vec x_1,\dots, \vec x_T}} \quad & \sum_{t=1}^{T} \left[ f_{\mathrm{state}}(\vec x_t) + \vec u_t^\top R \vec u_t + \theta_t^2+p_t^2\right]\\
#   \end{align*}
#
# Not all conditions are equally important at all points in time. For example: we want to use fast movement that is rich in kinetic energy to swing the pendulum upright in the beginning, but use only small movements to hold it there. We therefore also introduce a time series discount factor $\gamma$:
#
# \begin{align*}
#     \min_{\substack{\vec u_0,\dots \vec u_{T-1},\\\vec x_1,\dots, \vec x_T}} \quad & \sum_{t=1}^{T} \left[ (f_{\mathrm{state}}(\vec x_t) + \vec u_t^\top R \vec u_t + p_t^2)\cdot \gamma t +\theta_t^2\right]\\
#   \end{align*}
#
# This objective will be expressed by $\tilde{x_T^\top} Q \tilde{x_T}$ with the cost matrix $Q$ and
# \begin{align*}
# \tilde{\vec x}_T = \begin{pmatrix}
# \theta_1\\
# p_1\\
# \dot{\theta_1}\\
# \dot{p_1}\\
# u_1\\
# \theta_2\\
# p_2\\
# \vdots\\
# \dot{\theta_T}\\
# \dot{p_T}\\
# u_T
# \end{pmatrix}
# \end{align*}.
#
# This means
#
# \begin{align*}
#     \sum_{t=1}^{T} \left[ (f_{\mathrm{state}}(\vec x_t) + \vec u_t^\top R \vec u_t + p_t^2)\cdot \gamma t +\theta_t^2\right] =  \tilde{x_T^\top} Q \tilde{x_T} \\
#   \end{align*}

# %%
unicodeplots()
using SparseArrays

# %%
using PyPlot
# Out:
# WARNING: using PyPlot.plot in module Main conflicts with an existing identifier.
# WARNING: using PyPlot.scatter in module Main conflicts with an existing identifier.

# %%
time_discount
# Out:
# 0.1

# %%
# input is the state and the previously computed control u
# output is the control in this period
function mpc_pendulum_policy(x0,u_old)
      
    xt = simulate_pendulum(x0,u_old)
   
    # construct Matrix A_tilde and b_tilde for the equality constraints

    # kronecker product of two matrices --> new matrix has size = (T*k,T*n)
    A_tilde = kron(Matrix{Float64}(LA.I,T,T), -Matrix{Float64}(LA.I, k, n))
    b_tilde = zeros(k*T)
    
    b_tilde[1:length(x0)] = -x0 # Set first elements of b_tilde with x0
    
    for t=1:T-1
        # calculate At, bt and ct for each time step
        A_tmp, b_tmp, c_tmp = At_bt_ct(xt[t][1],xt[t][3])
        # construct Matrix A_tilde and b_tilde
        A_tilde[(t*k)+1:(t+1)*k,((t-1)*n)+1:t*n] = hcat(A_tmp,b_tmp)
        b_tilde[(t*k)+1:(t+1)*k] = -c_tmp
    end
    # PyPlot.spy(A_tilde)
    # PyPlot.plt.axis("off")
    
    #calculate the cost matrix Q 
    Q = zeros(n*T,n*T)
    for t=1:T-1
        θ = xt[t][1]
        c = cos(θ)
        s = sin(θ)

        t_tilde = 2*t^0.8
        
        #Our first objective is to get the pendulum upright and then hold that position in the centre of the line with at best not movement
        #not all objectives are similar important over time. time_discount*t enables us to reweight costs based on the passage of time.
        #make the pendulum upright and centered
        Q[((t-1)*n)+1,((t-1)*n)+1] = 100
        # Q[((t-1)*n)+2,((t-1)*n)+2] = time_discount^t
        Q[((t-1)*n)+2,((t-1)*n)+2] = time_discount*t_tilde
        
        #minimize kinetic energy in the system
        # ============================================================================================
        # fill the matrix Q with the terms of the objective function that are representing the kinetic
        # energy ot the system
        Q[((t-1)*n)+3,((t-1)*n)+3] = (0.5*m*l*l*(c*c+s*s))*time_discount*t
        Q[((t-1)*n)+4,((t-1)*n)+4] = (0.5*c+0.5*m)*time_discount*t
        Q[((t-1)*n)+3,((t-1)*n)+4] = (l*m*s)*time_discount*t
        # ============================================================================================
        
        #punish for large control values, if zero we might break the pendulum simulation, but you are encouraged to experiment
        Q[((t-1)*n)+5,((t-1)*n)+5] = 0.001
    end
    PyPlot.spy(Q)
    
    # ============================================================================================
    # setup the optimization problem and solve it using the COSMO solver --> simply exchange 
    # SCS.Optimizer by COSMO.Optimizer during model creation
    # define the objective and constraints using the JuMP package
    # model = Model(with_optimizer(COSMO.Optimizer));

    model = Model(COSMO.Optimizer)
    @variable(model, x[1:n*T]);
    @constraint(model, A_tilde * x .== b_tilde);#
    
    @objective(model, Min, x' * Q * x )
    optimize!(model)
    
    # extract the sequence of control values from the solution
    u_new = zeros(T)
    
    xt_ut = value.(x)
    u_new = [xt_ut[i] for i=5:5:T*5]
    # ============================================================================================
    return u_new
end
# Out:
# mpc_pendulum_policy (generic function with 1 method)

# %%
# Run the model predictive control
# x0: initial pendulum state
# time_sim: time for which the simulation should be run. This NOT the prediction horizon!
function run_mpc(x0,time_sim)
    
    # trace of pendulum state (rows 1-4) and control values (row 5)
    trace = zeros(length(x0)+1, time_sim) # the last entry at each t is the control value u
    
    # vector storing control values for the prediction horizon
    U = zeros(T)

    # copy of inital state
    x = copy(x0)
    
    # iterate over time steps
    for t=1:time_sim
        # compute the control by assuming the last control sequence as the starting point
        U[:] = mpc_pendulum_policy(x, U)

        # store the trace of all pendulum state and control for each time step
        trace[:,t] = vcat(x, U[1])

        # propagate pendulum one time step
        xt = simulate_pendulum(x,U[1]) 
        
        x[:] = xt[1]
    end
    return trace
end
# Out:
# run_mpc (generic function with 1 method)

# %%
# initial pendulum state
x0 = [pi, 0, 0, 0]
time_sim = 500
trace = run_mpc(x0, time_sim)
# Out:
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.31ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 9.9362e+03	2.9904e+00	9.5634e-04	1.0000e-01
# 25	 6.2834e+03	3.0223e-11	5.6574e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 6283
# Runtime: 0.0s (0.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 2.64ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 8.5244e+03	6.3048e+00	9.3005e-04	1.0000e-01
# 25	 5.6710e+03	6.1450e-14	7.0340e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 5671
# Runtime: 0.149s (149.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 4.15ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 6.4360e+03	7.8245e+00	8.5740e-04	1.0000e-01
# 25	 4.4097e+03	1.6445e-13	1.3566e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 4410
# Runtime: 0.017s (17.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 3.12ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 4.7337e+03	7.3747e+00	7.6376e-04	1.0000e-01
# 25	 3.6157e+03	8.6980e-12	2.1404e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 3616
# Runtime: 0.157s (157.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.37ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 3.9460e+03	6.3564e+00	6.7700e-04	1.0000e-01
# 25	 2.6370e+03	3.5243e-11	1.1656e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 2637
# Runtime: 0.0s (0.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 2.86ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 3.1716e+03	5.7455e+00	6.0095e-04	1.0000e-01
# 25	 2.6408e+03	9.6101e-13	1.6078e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 2641
# Runtime: 0.014s (14.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.68ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 2.5954e+03	4.9211e+00	5.3669e-04	1.0000e-01
# 25	 1.8162e+03	4.8857e-11	9.5964e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 1816
# Runtime: 0.005s (5.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.31ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 2.2334e+03	4.4650e+00	4.8201e-04	1.0000e-01
# 25	 2.3248e+03	3.8225e-11	6.6321e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 2325
# Runtime: 0.004s (4.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 3.15ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.7445e+03	3.9542e+00	4.3470e-04	1.0000e-01
# 25	 1.5064e+03	2.9332e-10	1.7133e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 1506
# Runtime: 0.0s (0.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 3.43ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.5265e+03	3.5806e+00	3.9241e-04	1.0000e-01
# 25	 1.2048e+03	3.7287e-11	9.2244e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 1205
# Runtime: 0.029s (29.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.63ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.2088e+03	3.2627e+00	3.5348e-04	1.0000e-01
# 25	 9.7798e+02	1.0813e-11	1.7183e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 978
# Runtime: 0.0s (0.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 9.95ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.2145e+03	3.0799e+00	3.1625e-04	1.0000e-01
# 25	 1.6464e+03	7.4687e-12	6.6798e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 1646
# Runtime: 0.059s (59.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 2.36ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 7.8533e+02	2.9957e+00	2.7844e-04	1.0000e-01
# 25	 1.0396e+03	5.7381e-10	1.4294e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 1040
# Runtime: 0.012s (12.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 3.11ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 7.2147e+02	2.6611e+00	2.4041e-04	1.0000e-01
# 25	 6.4361e+02	2.8240e-12	1.6425e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 643.6
# Runtime: 0.018s (18.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.52ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 5.1783e+02	2.3968e+00	2.0506e-04	1.0000e-01
# 25	 5.3904e+02	6.3555e-13	1.1254e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 539
# Runtime: 0.0s (0.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.42ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 5.2337e+02	2.2502e+00	1.7221e-04	1.0000e-01
# 25	 9.1765e+02	6.7104e-12	1.0704e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 917.7
# Runtime: 0.159s (159.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 6.48ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 4.4138e+02	2.1159e+00	1.3956e-04	1.0000e-01
# 25	 3.6043e+02	5.7193e-12	6.8456e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 360.4
# Runtime: 0.025s (25.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 2.35ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 3.9609e+02	1.7809e+00	1.0895e-04	1.0000e-01
# 25	 1.0035e+03	2.8166e-12	1.5025e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 1004
# Runtime: 0.011s (11.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 4.73ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 3.1477e+02	1.4005e+00	8.3453e-05	1.0000e-01
# 25	 3.0768e+02	9.7877e-12	9.5022e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 307.7
# Runtime: 0.019s (19.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.28ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 3.6804e+02	1.1590e+00	1.0424e-04	1.0000e-01
# 25	 7.3672e+02	5.2071e-13	1.4645e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 736.7
# Runtime: 0.006s (6.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 77.26ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 3.3708e+02	9.5440e-01	4.5055e-05	1.0000e-01
# 25	 3.0143e+02	6.7613e-13	1.1068e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 301.4
# Runtime: 0.127s (127.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 2.61ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 2.6032e+02	7.1366e-01	4.9966e-05	1.0000e-01
# 25	 7.8951e+02	2.4549e-11	4.3477e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 789.5
# Runtime: 0.013s (13.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.62ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 3.2585e+02	8.7255e-01	4.3679e-05	1.0000e-01
# 25	 3.0909e+02	2.2524e-12	1.2310e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 309.1
# Runtime: 0.156s (156.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 26.93ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 2.1214e+02	4.7835e-01	4.2123e-05	1.0000e-01
# 25	 5.6657e+02	7.4834e-11	9.8227e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 566.6
# Runtime: 0.057s (57.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 4.91ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 2.3455e+02	2.9341e-01	4.1396e-05	1.0000e-01
# 25	 1.1943e+03	2.0277e-11	7.3197e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 1194
# Runtime: 0.019s (19.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 4.46ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 2.6152e+02	6.9744e-01	4.2141e-05	1.0000e-01
# 25	 1.9839e+02	8.8569e-12	4.8231e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 198.4
# Runtime: 0.015s (15.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 2.45ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 3.4083e+02	2.9271e-01	7.4643e-05	1.0000e-01
# 25	 6.4112e+02	8.8840e-13	3.1401e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 641.1
# Runtime: 0.199s (199.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 4.52ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 2.4809e+02	6.2686e-01	4.5173e-05	1.0000e-01
# 25	 2.8613e+02	5.1705e-12	9.4790e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 286.1
# Runtime: 0.016s (16.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.44ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.7989e+02	4.4614e-01	3.7393e-05	1.0000e-01
# 25	 7.1629e+02	4.5836e-11	1.5829e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 716.3
# Runtime: 0.009s (9.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.39ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 2.6175e+02	4.9560e-01	4.7285e-05	1.0000e-01
# 25	 4.3461e+02	5.8487e-13	4.6891e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 434.6
# Runtime: 0.017s (17.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.85ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.9737e+02	3.3417e-01	4.5219e-05	1.0000e-01
# 25	 3.2548e+02	4.5427e-11	3.8090e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 325.5
# Runtime: 0.019s (19.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 5.35ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.9029e+02	4.7798e-01	3.3858e-05	1.0000e-01
# 25	 8.6582e+02	1.3512e-10	1.0626e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 865.8
# Runtime: 0.012s (12.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 10.84ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 2.5953e+02	6.1480e-01	4.4170e-05	1.0000e-01
# 25	 3.2822e+02	2.4668e-12	6.2556e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 328.2
# Runtime: 0.146s (146.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 3.95ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 8.0271e+00	1.9151e-01	6.2066e-06	1.0000e-01
# 25	 5.6637e+01	1.3975e-11	1.5153e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 56.64
# Runtime: 0.012s (12.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 3.52ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 2.0762e+02	4.1917e-01	4.1281e-05	1.0000e-01
# 25	 5.2086e+02	2.2538e-11	1.2382e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 520.9
# Runtime: 0.017s (17.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 3.67ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 2.3853e+02	4.8340e-01	4.3776e-05	1.0000e-01
# 25	 2.7211e+02	1.9282e-11	4.0768e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 272.1
# Runtime: 0.073s (73.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.39ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 2.1075e+02	4.7805e-01	7.0572e-05	1.0000e-01
# 25	 6.6761e+02	2.5099e-11	2.8075e-11	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 667.6
# Runtime: 0.0s (0.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 4.7ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 2.1559e+02	4.6545e-01	4.2725e-05	1.0000e-01
# 25	 3.6116e+02	6.9866e-12	1.6628e-12	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 361.2
# Runtime: 0.021s (21.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 2.54ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 9.5360e+01	3.6441e-01	7.0939e-05	1.0000e-01
# ...
# Optimal objective: 41.15
# Runtime: 0.008s (8.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 2.97ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.0770e+00	2.0017e-01	8.0153e-07	1.0000e-01
# 25	 4.1463e+01	8.4384e-13	2.4038e-13	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 41.46
# Runtime: 0.008s (8.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 3.56ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.0850e+00	2.0091e-01	8.0465e-07	1.0000e-01
# 25	 4.1777e+01	8.5532e-13	2.8243e-13	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 41.78
# Runtime: 0.008s (8.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.83ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.0931e+00	2.0165e-01	8.0779e-07	1.0000e-01
# 25	 4.2094e+01	8.7177e-13	2.1062e-13	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 42.09
# Runtime: 0.0s (0.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 2.49ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.1013e+00	2.0240e-01	8.1093e-07	1.0000e-01
# 25	 4.2414e+01	8.6474e-13	2.1873e-13	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 42.41
# Runtime: 0.007s (7.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 2.37ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.1095e+00	2.0315e-01	8.1409e-07	1.0000e-01
# 25	 4.2736e+01	8.7082e-13	3.4029e-13	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 42.74
# Runtime: 0.008s (8.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 3.66ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.1178e+00	2.0391e-01	8.1727e-07	1.0000e-01
# 25	 4.3061e+01	8.8343e-13	2.5972e-13	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 43.06
# Runtime: 0.017s (17.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 82.1ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.1261e+00	2.0466e-01	8.2045e-07	1.0000e-01
# 25	 4.3388e+01	8.6627e-13	3.0455e-13	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 43.39
# Runtime: 0.099s (99.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 2.7ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.1345e+00	2.0542e-01	8.2365e-07	1.0000e-01
# 25	 4.3718e+01	8.8152e-13	2.2177e-13	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 43.72
# Runtime: 0.005s (5.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 6.79ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.1430e+00	2.0619e-01	8.2686e-07	1.0000e-01
# 25	 4.4050e+01	8.8746e-13	2.2810e-13	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 44.05
# Runtime: 0.019s (19.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.58ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.1516e+00	2.0696e-01	8.3008e-07	1.0000e-01
# 25	 4.4385e+01	8.8359e-13	2.0371e-13	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 44.39
# Runtime: 0.01s (10.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.6ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.1602e+00	2.0773e-01	8.3332e-07	1.0000e-01
# 25	 4.4723e+01	8.7896e-13	3.9222e-13	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 44.72
# Runtime: 0.077s (77.0ms)
# Excessive output truncated after 524605 bytes.
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Settings: ϵ_abs = 1.0e-05, ϵ_rel = 1.0e-05,
#           ϵ_prim_inf = 1.0e-04, ϵ_dual_inf = 1.0e-04,
#           ρ = 0.1, σ = 1e-06, α = 1.6,
#           max_iter = 5000,
#           scaling iter = 10 (on),
#           check termination every 25 iter,
#           check infeasibility every 40 iter,
#           KKT system solver: QDLDL
# Acc:      Anderson Type2{QRDecomp},
#           Memory size = 15, RestartedMemory,
#           Safeguarded: true, tol: 2.0
# Setup Time: 1.85ms
#
# Iter:	Objective:	Primal Res:	Dual Res:	Rho:
# 1	 1.1689e+00	2.0850e-01	8.3657e-07	1.0000e-01
# 25	 4.5063e+01	9.2766e-13	2.3281e-13	1.0000e-01
#
# ------------------------------------------------------------------
# >>> Results
# Status: Solved
# Iterations: 25
# Optimal objective: 45.06
# Runtime: 0.016s (16.0ms)
#
# ------------------------------------------------------------------
#           COSMO v0.8.9 - A Quadratic Objective Conic Solver
#                          Michael Garstka
#                 University of Oxford, 2017 - 2022
# ------------------------------------------------------------------
#
# Problem:  x ∈ R^{250},
#           constraints: A ∈ R^{200x250} (690 nnz),
#           matrix size to factor: 450x450,
#           Floating-point precision: Float64
# Sets:     ZeroSet of dim: 200
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 5×500 Matrix{Float64}:
#     3.14159     3.04795      2.79725     2.48633   …  -0.00123156  -0.00123589   -0.00124024   -0.00124462
#     0.0        -0.0468229   -0.172727   -0.330779     -0.704139    -0.706844     -0.70956      -0.712286
#     0.0        -6.24305    -10.4702    -10.2579       -0.00014397  -0.000144691  -0.000145413  -0.000146136
#     0.0        -3.12153     -5.27205    -5.26479      -0.0899861   -0.0903482    -0.0907115    -0.0910762
#  -832.407    -580.199      -41.2504    176.046        -0.12072     -0.121145     -0.121571     -0.122

# %%
p_optimized = trace[2,:]
θ_optimized = trace[1,:]

animate_pendulum(p_optimized,θ_optimized,"mpc_pendulum")
# Out:
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9.3.1 (GCC) 20200523
#   configuration: --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libmfx --enable-amf --enable-ffnvcodec --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'tmp/mpc_pendulum_%02d.png':
#   Duration: 00:00:33.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 2000x600, 15.17 fps, 15.15 tbr, 15.15 tbn, 15.15 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 000002185b3a7b00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 000002185b3a7b00] profile High 4:4:4 Predictive, level 3.2, 4:4:4, 8-bit
# [libx264 @ 000002185b3a7b00] 264 - core 160 - H.264/MPEG-4 AVC codec - Copyleft 2003-2020 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=19 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'mpc_pendulum.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 2000x600, q=-1--1, 15.15 fps, 30303 tbn, 15.15 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  500 fps=161 q=-1.0 Lsize=      89kB time=00:00:32.80 bitrate=  22.3kbits/s speed=10.6x
# video:83kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 7.993433%
# [libx264 @ 000002185b3a7b00] frame I:2     Avg QP:12.23  size:   924
# [libx264 @ 000002185b3a7b00] frame P:136   Avg QP:17.44  size:   298
# [libx264 @ 000002185b3a7b00] frame B:362   Avg QP:20.03  size:   115
# [libx264 @ 000002185b3a7b00] consecutive B-frames:  2.4%  2.8%  1.2% 93.6%
# [libx264 @ 000002185b3a7b00] mb I  I16..4: 28.7% 70.9%  0.4%
# [libx264 @ 000002185b3a7b00] mb P  I16..4:  0.2%  0.1%  0.0%  P16..4:  0.3%  0.1%  0.0%  0.0%  0.0%    skip:99.2%
# [libx264 @ 000002185b3a7b00] mb B  I16..4:  0.1%  0.0%  0.0%  B16..8:  0.5%  0.1%  0.0%  direct: 0.0%  skip:99.4%  L0:50.8% L1:38.4% BI:10.8%
# [libx264 @ 000002185b3a7b00] 8x8 transform intra:57.5% inter:33.4%
# [libx264 @ 000002185b3a7b00] coded y,u,v intra: 1.6% 0.7% 1.0% inter: 0.0% 0.0% 0.0%
# [libx264 @ 000002185b3a7b00] i16 v,h,dc,p: 85% 14%  1%  0%
# [libx264 @ 000002185b3a7b00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26%  2% 72%  0%  0%  0%  0%  0%  0%
# [libx264 @ 000002185b3a7b00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 45% 18% 28%  2%  2%  2%  2%  2%  1%
# [libx264 @ 000002185b3a7b00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 000002185b3a7b00] ref P L0: 55.4%  2.3% 23.8% 18.5%
# [libx264 @ 000002185b3a7b00] ref B L0: 56.7% 32.0% 11.3%
# [libx264 @ 000002185b3a7b00] ref B L1: 85.2% 14.8%
# [libx264 @ 000002185b3a7b00] kb/s:20.36
# Process(`ffmpeg -y -framerate 15.1515 -i tmp/mpc_pendulum_%02d.png mpc_pendulum.mp4`, ProcessExited(0))

# %%
trace[:,end]
# Out:
# 5-element Vector{Float64}:
#  -0.0012446152767698073
#  -0.7122863314379583
#  -0.00014613644586201533
#  -0.09107616027580376
#  -0.12200026435165812

# %%
trace[:,end-10]
# Out:
# 5-element Vector{Float64}:
#  -0.0012018546577153785
#  -0.6855050249677548
#  -0.0001389502674765343
#  -0.08748658670694197
#  -0.1178067430350952
